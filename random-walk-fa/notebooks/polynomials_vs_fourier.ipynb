# %% [markdown]
# # Polynomials VS Fourier Basis

# %% [markdown]
# - Figure 9.5 shows learning curves comparing the Fourier and polynomial bases on the 1000-state random walk example.
# - In general, we do not recommend using polynomials for online learning.
#   - There are families of polynomials more complicated than those we have discussed, for example, different families of orthogonal polynomials, and these might work better, but at present there is little experience with them in RL.

# %%
from IPython.display import Image

# %%
Image(filename="../book_images/Figure_9_5.PNG")

# %%
import numpy as np
from tqdm import tqdm
import matplotlib
import matplotlib.pyplot as plt

matplotlib.use('Agg')

# %%
from src.random_walk import compute_true_value, BasesValueFunction, basis_types, states, gradient_monte_carlo

# %%
# Compute the true values of states
true_values = compute_true_value()

# %%
# Number of runs


# Number of episodes

# %%
# Number of bases


# Step-size parameters

# %%
# There are 2 bases: polynomial and Fourier, and 3 orders for each basis => 2 * 3 = 6 labels in total


# Track errors for each episode

# %%
# For every run

    # for every order
    
        # initialize VFs for polynomial basis and Fourier basis
        
        
        # for every VF
        
            # for every episode
            

                # gradient MC algorithm
                

                # get state values under current value function
                

                # get the root-mean-squared error

# %%
# Average over independent runs

# %%
# Plotting
for i in range(len(step_sizes)):
    for j in range(len(orders)):
        plt.plot(errors[i, j, :], label='%s order = %d' % (labels[i][j], orders[j]))

plt.xlabel("Episodes")

# The book plots RMS-VE, which is RMSE weighted by a state distribution
plt.ylabel(r'$\sqrt{\overline{VE}}$')

plt.legend()

# %%
plt.savefig("../generated_images/figure_9_5.png")
plt.close()
