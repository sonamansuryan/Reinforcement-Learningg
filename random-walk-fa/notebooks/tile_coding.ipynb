# %% [markdown]
# # Tile Coding

# %% [markdown]
# Figure 9.10 shows the advantage of multiple o↵set tilings (coarse coding) over a single tiling on the 1000-state random walk example.

# %%
from IPython.display import Image

# %%
Image(filename="../book_images/Figure_9_10.PNG")

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm

matplotlib.use('Agg')

# %%
from src.random_walk import compute_true_value, TilingsValueFunction, ValueFunction, states_number, gradient_monte_carlo, states

# %%
# Compute the true values of states
true_values = compute_true_value()

# %%
# Number of runs


# Number of episodes

# %%
# Number of tilings


# Each tile will cover 200 states


# How to put so many tilings

# %%
# Labels


# Track errors for each episode

# %%
# For every run

    # initialize value functions for multiple tilings and single tiling
    
    
    # for every VF
    
        # for every episode
        
            # use a changing step-size parameter (denoted as 𝛼) according to the episode instead of a small fixed 𝛼 because
            # with a small fixed 𝛼, 5000 episodes may not be enough for so many parameters in multiple tilings.
            # The asymptotic performance for single tiling stays unchanged under a changing 𝛼,
            # however the asymptotic performance for multiple tilings improves significantly
            

            # gradient MC algorithm
            

            # get state-values under current VF
            

            # get the root-mean-squared error

# %%
# Average over independent runs

# %%
# Plotting
for i in range(len(labels)):
    plt.plot(errors[i], label=labels[i])

plt.xlabel("Episodes")

# The book plots RMS-VE, which is RMSE weighted by a state distribution
plt.ylabel(r"$\sqrt{\overline{VE}}$")

plt.legend()

# %%
plt.savefig("../generated_images/figure_9_10.png")
plt.close()
